# %% [markdown]
# # Import Required Libraries
# Import libraries needed for web scraping, data processing, and database operations, including requests_html, BeautifulSoup, pymongo, json, re, and csv.

# %%
# Import Required Libraries

from requests_html import HTMLSession
from bs4 import BeautifulSoup
from pymongo import MongoClient
import json
import re
import csv
import requests

# %% [markdown]
# # Extract Laptop Links
# Use requests_html HTMLSession to navigate through pagination and collect all laptop URLs from appinformatica.com/ordenadores/ordenadores-portatiles, similar to the PCBox implementation.

# %%
# Extract Laptop Links

session = HTMLSession()
laptop_links = []

for i in range(1, 21):
    print(f'Pagina {i}')
    r = session.get(url=f"https://www.appinformatica.com/ordenadores/ordenadores-portatiles?page={i}")
    
    # Get all links with the specified class
    links = r.html.find('a.vtex-product-summary-2-x-clearLink.vtex-product-summary-2-x-clearLink--main-product-summary.h-100.flex.flex-column')
    # Extract absolute URLs and remove duplicates
    links = list(set([link.absolute_links.pop() for link in links]))
    laptop_links.extend(links)

laptop_links
# Out:
# Pagina 1
# Pagina 2
# Pagina 3
# Pagina 4
# Pagina 5
# Pagina 6
# Pagina 7
# Pagina 8
# Pagina 9
# Pagina 10
# Pagina 11
# Pagina 12
# Pagina 13
# Pagina 14
# Pagina 15
# Pagina 16
# Pagina 17
# Pagina 18
# Pagina 19
# Pagina 20
# ['https://www.appinformatica.com/e1504fa-nj158w-portatil-asus-e1504fa-nj158w-amd-r5-7520u-4-3ghz--8gb--512gb-ssd/p',
#  'https://www.appinformatica.com/578b1ea-abe-15s-fq4038ns-i5-1155g7-512gb-8gb-15-6in-w-11/p',
#  'https://www.appinformatica.com/9rc55kf5feja01es000-portatil-gigabyte-g5-kf5-53es354sd-i5-13500h-4060-16gb-ddr5/p',
#  'https://www.appinformatica.com/82r4001csp-portatil-lenovo-ideapad-1-r5-8gb-512ssd-15-6--w11h/p',
#  'https://www.appinformatica.com/9rx6l9sgdsjhhdes000-gigabyte-portatil-aorus-16x-9sg-43esc64sh-i7-13650hx-32gb-d/p',
#  'https://www.appinformatica.com/nh-qpneb-009-portatil-gaming-acer-predator-helios-neo-16--nh-qpneb-009---core-u/p',
#  'https://www.appinformatica.com/9j1e1ea-abe-t-15-fd0031ns-ci3-n305-8gb-256gb-w11h/p',
#  'https://www.appinformatica.com/9rc6l9kghsja01es000-portatil-gigabyte-g6x-9kg-43es854sd-i7-136250hx-4060-16gb-d/p',
#  'https://www.appinformatica.com/83em00d6sp-ips3-15irh8-15-6fhd-tn-ag-250n-n-core-i7-13620h-2-4g-10c-16t--1tb-ss/p',
#  'https://www.appinformatica.com/90nr0jv7-m00550-portatil-asus-tuf-fa506ncr-hn077-r7-7435hs-16gb-512gb-15-6-fhd-/p',
#  'https://www.appinformatica.com/ak9z9at-portatil-hp-255-g10-r3-7330u-8gb-512gb-15-6--freedos/p',
#  'https://www.appinformatica.com/90nb1022-m011c0-portatil-asus-vivobook-f1504za-nj710-i7-1255u-15-6-fhd-16gb-512/p',
#  'https://www.appinformatica.com/9s7-15k111-1621-portatil-gaming-msi-cyborg-15-1621xes-i7-13620h--16gb---1tb-ssd/p',
#  'https://www.appinformatica.com/9s7-16r831-1490-msi-portatil-thin-15-b12ve-1490xes--15-6--fhd--1920-1080---144h/p',
#  'https://www.appinformatica.com/a13gdea-abe-16-ac0007ns-u7-155u-16-1-w11h/p',
#  'https://www.appinformatica.com/90nb14q2-m00cb0-portatil-asus-vivobook-s-s5507qa-ma124w-qualcomm-x1-16gb-512gb-/p',
#  'https://www.appinformatica.com/82r400kksp-ideapad-s100-ip1-15alc7-ryzen_7_5700u_1-8g_8c_mb-15-6fhd_tn_ag_220n_/p',
#  'https://www.appinformatica.com/a30ytea-abe-omen-17-r7-8845hs-32gb-ddr5-2dm-5600-1tb-rtx-4070-8gb-vram-avid-qhd/p',
#  'https://www.appinformatica.com/90nr0jp5-m006l0-asus-tuf507nur-lp11-amd-r7-7435-16-512-4050-dos-15/p',
#  'https://www.appinformatica.com/a30ymea-abe-omen-16-i9-14900hx-32gb-ddr5-2dm-5600-1tb-gen4-rtx-4060-8gb-vram-br/p',
#  'https://www.appinformatica.com/9s7-15a211-022-prestige-16-ai-studio-b1vfg-022-1tb-16gb-16in-rtx4060-8gb-w1-1h/p',
#  'https://www.appinformatica.com/a31bmea-portatil-hp-victus-16-r1026ns-i7-14650hx-16gb-1tb-rtx4060-16--freedos/p',
#  'https://www.appinformatica.com/90nb10j2-m02650-asus-f1504va-nj1709w-i5-1334u-8gb-512gb-w11h-15-6/p',
#  'https://www.appinformatica.com/um3504da-ma371w--lt--portatil-asus-um3504da-ma371w/p',
#  'https://www.appinformatica.com/90nb0zt1-m00rr0-portatil-asus-vivobook-go-e1504ga-nj463w-i3-n305-8gb-512gb-15-6/p',
#  'https://www.appinformatica.com/83jc001ssp-loq-15arp9-15-6-fhd-ag-300n-144-srgb-r7-7435hs-3-1g-8c-16t-24g-12-12/p',
#  'https://www.appinformatica.com/82ku006dsp-portatil-lenovo-ip-3-15alc6-amd-ryzen_7_5700u-1-8g--8gb--512gb-ssd--/p',
#  'https://www.appinformatica.com/nx-ejaeb-002-portatil-acer-extensa-15-ex215-57-intel-i5-1334u-15-6--fhd-16gb-51/p',
#  'https://www.appinformatica.com/b4xd8ea-abe-16-r1046ns-roaree-24c1-victus-16-win-11-core-i7-14650hx-32gb-ddr5-2/p',
#  'https://www.appinformatica.com/90nb1271-m007t0-asus-u3406ha-qd067w-amd-r7-8840hs-16gb-512-w11h-14/p',
#  'https://www.appinformatica.com/b4xd0ea-abe-14-fh0006ns-regis-24c2-hp-omnibook-ultra-flip-14-ultra-7-258v--8c--/p',
#  'https://www.appinformatica.com/nx-eg9eb-00l-portatil-acer-extensa-ex215-22-r32c--nx-eg9eb-00l--15-6--amd-ryzen/p',
#  'https://www.appinformatica.com/83en0002sp-ips3-16irh8-16-wuxga-ag-300n-n-core-i5-13420h-2-1g-8c-12t--1tb-ssd-m/p',
#  'https://www.appinformatica.com/oc-11040-portatil-reacondicionado-hp-elitebook-840-g5-14--full-hd---i5-8th---8g/p',
#  'https://www.appinformatica.com/e1504fa-nj643w-portatil-asus-vivobook-go-15-e1504fa-nj643w-amd-r5-7520u-2-8ghz-/p',
#  'https://www.appinformatica.com/9s7-158571-1853-msi-portatil--katana-15-b13vfk-1853xes-15-6--fhd--1920-1080---1/p',
#  'https://www.appinformatica.com/9s7-15k111-838-msi-portatil-cyborg-15-a13vf-838xes--15-6--fhd--1920-1080---144h/p',
#  'https://www.appinformatica.com/83a58ea-portatil-hp-victus-gaming-16-r0009ns-i7-13700h-16gb-512gb-16--rtx-4050-/p',
#  'https://www.appinformatica.com/6s7b5ea-portatil-hp-250-g9-6s7b5ea-i5-1235u-15-6-fhd-16gb-s512gb-widi-ac-fredoo/p',
#  'https://www.appinformatica.com/b5el6ea-portatil-hp-15-fd0173ns-celeron-n100-8gb-256gb-15-6--w11h/p',
#  'https://www.appinformatica.com/zhh-00037-laptop-cop-pc-15-c12-16gb-512g-bk-w11/p',
#  'https://www.appinformatica.com/6s6k8ea-portatil-hp-250-g9-i3-1215u-8gb-512ssd-15-6--w11h/p',
#  'https://www.appinformatica.com/83a100gesp-portatil-lenovo-v15-g4-iru-i5-13420h-15-6-fhd-16gb-512gb-rj45-usb-c-/p',
#  'https://www.appinformatica.com/83a100bhsp-lenovo-v15-i5-13420h-8gb-512gb-w11h-15-6-fhd/p',
#  'https://www.appinformatica.com/90nx06j1-m006y0-cx3402cba-pq0195-i3-1215u-14/p',
#  'https://www.appinformatica.com/82yu00trsp-lenovo-v15-amd-r5-7520u-8gb-256gb-w11h-15-6-fhd/p',
#  'https://www.appinformatica.com/a31byea-portatil-hp-victus-16-r1028ns--i7-14650hx-32gb-1tb-rtx4070-16-1--freedo/p',
#  'https://www.appinformatica.com/82tt00sesp-portatil-lenovo-v15-g4-abp-i3-1215u-16gb-2x8gb--ssd-512gb-15-6-fhd-f/p',
#  'https://www.appinformatica.com/9s7-15hk12-040-msi-portatil-modern-15-b7m-040es--15-6--fhd--1920-1080---60hz--r/p',
#  'https://www.appinformatica.com/ga403ui-qs049-portatil-asus-ga403ui-qs049/p',
#  'https://www.appinformatica.com/rz09-0510s1n3-r311-portatil-razer-blade-16--s10-nt-win-11-qhd--240hz-oled--1490/p',
#  'https://www.appinformatica.com/nx-ahbeb-007-cp514-2h-14-ci5-1x8gb-256ssd-chrome/p',
#  'https://www.appinformatica.com/9j1d7ea-abe-cs-14-ek1048ns-i5-1335u-16g512-14--w11h/p',
#  'https://www.appinformatica.com/83a100kqsp-lenovo-v15-i3-1315u-8gb-512gb-dos-15-6-fhd/p',
#  'https://www.appinformatica.com/82yy001psp-lenovo-v15-amd-r7-7730u-16gb-512gb-w11h-15-6-fhd/p',
#  'https://www.appinformatica.com/83a2001ksp-portatil-lenovo-v17-g4-iru-i7-1355u-17-3-fhd-16gb-512gb-usb-c-wifi-6/p',
#  'https://www.appinformatica.com/724n8ea-portatil-hp-250-g9-724n8ea-i7-1255u-15-6-fhd-16gb-s512gb-wifi-ac-fredoo/p',
#  'https://www.appinformatica.com/82xv00bssp-loq-15irh8-corei5-12450h2-0g8c12t-16gb-8-8--512gbssdm-22242g4tlc-rtx/p',
#  'https://www.appinformatica.com/mrx83y-a-disco-duro-ssd-800gb-2-5---lenovo-4xb7a17062-1000mb-s-12gbit-s--sas/p',
#  'https://www.appinformatica.com/82y700d7sp-yoga-s700-ygpro7-14irh8-i7-13700h_2-4g_14c_20t-14-5_wqxga_ag_350n_90/p',
#  'https://www.appinformatica.com/am1c8ea-32gb-portatil-hp-victus-15-fb2010ns-r7-8845hs-32gb-1tb-rtx-4050-15-6--f/p',
#  'https://www.appinformatica.com/83a000afsp-lenovo-v14-g4-i5-13420h-8gb-512gb-w11h-14-fhd/p',
#  'https://www.appinformatica.com/mtl83y-a-monitor-asus-vs278q---27--1920-x-1080-hdmi-vga-altavoces/p',
#  'https://www.appinformatica.com/83bn002lsp-nb-ip3-cb-14ian8-i3-8gb---chrome-plus/p',
#  'https://www.appinformatica.com/9s7-15g311-004-msi-creator-z16hxs-004es-i7-13-32-1tb-4060-w11h-16/p',
#  'https://www.appinformatica.com/ty3dj-portatil-dell-inspiron-3535-r7-7730u-16gb-512gb-15-6-fhd-w11h/p',
#  'https://www.appinformatica.com/ak2f7ea-abe-hp-omnibook-x-14-qc-snapdragon-x1e-78-100--12c--16gb-lpddr5x-1tb-ge/p',
#  'https://www.appinformatica.com/9s7-13q222-025-msi-prestige-13-ai-025es-ultra7-16-1tb-arc-w11h-13/p',
#  'https://www.appinformatica.com/e1504ga-nj467w-portatil-asus--e1504ga-nj467w-core-i3-n305-3-8ghz--8gb--256gb-ss/p',
#  'https://www.appinformatica.com/9s7-15f412-043-stealth-16-ai-studio-a1vfg-043x-1tb-32gbg-16in-rtx4060-8gb-no-os/p',
#  'https://www.appinformatica.com/82tt00kbsp-lenovo-v15-i3-1215u-8gb-256gb-dos-15-6-fhd/p',
#  'https://www.appinformatica.com/b59zbea-hp-portatiles-b59zbea/p',
#  'https://www.appinformatica.com/9s7-14n211-016-prestige-14-ai-studio-c1veg-016-1tb-16gb-14in-rtx4050-6gb-w1-1h/p',
#  'https://www.appinformatica.com/9rc56kf0hdik0ies000-portatil-gigabyte-g6-kf-73es893kd-i7-13700h-16gb-512gb-16-f/p',
#  'https://www.appinformatica.com/9rx6lasgddjhhdpt001-portatil-gigabyte-aorus-16x-asg-53ptc64sh-i7-14650hx-4070-3/p',
#  'https://www.appinformatica.com/nx-aygeb-001-cb515-1w-54xc-chrome-8g-128g/p',
#  'https://www.appinformatica.com/9rc56mf0hdik0ies000-portatil-gigabyte-g6-mf-72es893kd-i7-13620h-16gb-512gb-15-6/p',
#  'https://www.appinformatica.com/30038275-portatil-medion-akoya-e16433-i7-1255u-16gb-1tb-16--w11/p',
#  'https://www.appinformatica.com/83em00fcsp-ips3-15irh8-i5-13420h-16-1tb-w11h/p',
#  'https://www.appinformatica.com/984d0ea-abe-16-wd0008nsi7-13620h32-140608dos/p',
#  'https://www.appinformatica.com/9s7-15a211-026-portatil-msi-prestige-16-ai-026es-core-ultra-7-155h-hsta-4-8ghz-/p',
#  'https://www.appinformatica.com/mly43y-a-macbook-air-13--apple-m2-8-core-and-10-core-gpu-512gb-midnight/p',
#  'https://www.appinformatica.com/mr7k3y-a-televisor-sony-49---fw-49bz35f-lcd-4k-ultra-hd/p',
#  'https://www.appinformatica.com/m1502ya-nj151--neo--portatil-asus-m1502ya-nj151--15-6--fhd--ryzen-7-7730u--16gb/p',
#  'https://www.appinformatica.com/98k26et-abe-zbfury-i9-14900hx-64gb-1tb-rtx-w11p/p',
#  'https://www.appinformatica.com/mxd33y-a-disco-duro-2000gb-2-5---lenovo---7xb7a00037-serial-ata-iii/p',
#  'https://www.appinformatica.com/mc9g4y-a-mba-15-3-midnight-10c-gpu-16gb-256gb/p',
#  'https://www.appinformatica.com/21ke002ysp-lenovo-x1-2-in-1-g9-tb-7-155u-16gb-512gb-w11p/p',
#  'https://www.appinformatica.com/83lk007csp-loq-15iax9e---15-6-fhd-i7-12650hx-16-512-rtx4050-w11-grey/p',
#  'https://www.appinformatica.com/82r400wssp-ip1-15amn7-ryz5-5625u-16-512gb-w11h/p',
#  'https://www.appinformatica.com/82yu00tlsp-lenovo-v15-amd-r3-7320u-8gb-256gb-w11h-15-6-fhd/p',
#  'https://www.appinformatica.com/hn7306wv-lx011w-portatil-asus-proart-px13-oled-hn7306wv-lx011w--13-3--3k--ryzen/p',
#  'https://www.appinformatica.com/ux8406ma-ql396w-portatil-asus-zenbook-duo-oled-ux8406ma-pz255w--14-tactil-1920x/p',
#  'https://www.appinformatica.com/15z90s-g-ad78b-lg-15z90s-ultra7-32gb-1tb-w11h-15-ips-negro/p',
#  'https://www.appinformatica.com/ar9a6ea-hp-portatiles-ar9a6ea/p',
#  'https://www.appinformatica.com/zgp-00048-laptop-cop-pc-13-8-c12-16g-512g-bk-w11/p',
#  'https://www.appinformatica.com/16z90s-g-ad7bb-lg-16z90s-ultra7-155h-32gb-2tb-w11h-16-ips/p',
#  'https://www.appinformatica.com/16zd90s-g-ax75b-portatil-lg-gram-u7-155h-16gb-512gb-16-wqxga-freedos/p',
#  'https://www.appinformatica.com/a30yyea-abe-omen-17-r7-8845hs-32gb-ddr5-2dm-5600-1tb-rtx-4060-8gb-vram-avid-ant/p',
#  'https://www.appinformatica.com/nx-egyeb-00j-portatil-acer-ex215-55-73qx-intel-i7-1255u-15-6--8gb-512gb-rj45-hd/p',
#  'https://www.appinformatica.com/90nb14u1-m00340-portatil-asus-zenbook-um3406ka-qd074w-r7-350-16gb-512gb-ssd-14-/p',
#  'https://www.appinformatica.com/16z90r-e-ad78b-portatil-lg-gram-i7-1360p-32gb-1tb-rtx3050-16-wqxga-w11h/p',
#  'https://www.appinformatica.com/15zd90s-g-ax75b-lg-15zd90s-ultra7-16gb-512tb-dos-15-ips-negro/p',
#  'https://www.appinformatica.com/b4xl6ea-abe-16-r1047ns-roaree-24c1-victus-16-freedos-core-i7-14650hx-32gb-ddr5-/p',
#  'https://www.appinformatica.com/9m4e3at-abe-hp-ebultrag1q-x1e7810-14-32gb-1t-pc-spai/p',
#  'https://www.appinformatica.com/6f1z7ea-hp-250-g9-6f1z7ea-i3-1215u-8gb-256gb-dos-15-6/p',
#  'https://www.appinformatica.com/6s6k7ea-portatil-hp-250-g9-i5-1235u-8gb-256gb-15-6--w11h/p',
#  'https://www.appinformatica.com/9rx6l9sgdsjhhdes0p0-portatil-gigabyte-aorus-16x-9sg-43esc64sh-i7-13650hx-4070-3/p',
#  'https://www.appinformatica.com/9w206ea-portatil-hp-victus-15-fa0049ns-i7-12650h-16gb-512gb-rtx-3050-15-6--free/p',
#  'https://www.appinformatica.com/nx-egyeb-01b-portatil-acer-ext215-55-i7-1255u-8gb-512gb-15-6--fhd-1920x1080-w11/p',
#  'https://www.appinformatica.com/zhg-00012-laptop-cop-pc-15-c12-16g-256g-plat-w11/p',
#  'https://www.appinformatica.com/82yu00tssp-lenovo-v15-amd-r5-7520u-8gb-512gb-w11h-15-6-fhd/p',
#  'https://www.appinformatica.com/83a66ea-portatil-hp-victus-16-s0009ns-r7-7840hs-16gb-512gb-rtx-4050-16-fhd-free/p',
#  'https://www.appinformatica.com/6f205ea-16gb-portatil-hp-250-g9-i7-1255u-16gb-512gb-15-6--w11h/p',
#  'https://www.appinformatica.com/8a4y4ea-abe-hp-255-g10-r7-7530u-16-512-w11h/p',
#  'https://www.appinformatica.com/806z4ea-portatil-hp-victus-15-fa0052ns-i5-12450h-16gb-512gb-15-6--rtx-3050-free/p',
#  'https://www.appinformatica.com/96y63et-abe-hp-eb1040g11-u7-155h-14-32gb-1t-pc/p',
#  'https://www.appinformatica.com/6s7b5ea-16gb-portatil-hp-250-i5-1235u-16gb-512ssd-15-6--freedos/p',
#  'https://www.appinformatica.com/6s6f4ea-hp-255-g9-6s6f4ea-amd-r5-5625u-8gb-512gb-w11h-15-6/p',
#  'https://www.appinformatica.com/mx2k3y-a-mbp-14-space-black-14c-32c-gpu-36gb-1t/p',
#  'https://www.appinformatica.com/mrym3y-a-mba-15-3--m3-sp-gray-10c-gpu-8gb-256gb/p',
#  'https://www.appinformatica.com/mryn3y-a-mba-15-3--m3-sp-gray-10c-gpu-8gb-512gb/p',
#  'https://www.appinformatica.com/mryu3y-a-mba-15-3--m3-midnight-10c-gpu-8gb-256gb/p',
#  'https://www.appinformatica.com/mc9d4y-a-mba-15-3-space-gray-10c-gpu-16gb-256gb/p',
#  'https://www.appinformatica.com/mc7w4y-a-mba-13-6-starlight-8c-gpu-16gb-256gb/p',
#  'https://www.appinformatica.com/mc7u4y-a-mba-13-6-space-gray-8c-gpu-16gb-256gb/p',
#  'https://www.appinformatica.com/mqrq3y-a-televisor-sony-49---fw-49bz35f-lcd-4k-ultra-hd/p',
#  'https://www.appinformatica.com/mc8n4y-a-mba-13-6-silver-10c-gpu-24gb-512gb/p',
#  'https://www.appinformatica.com/21ml0024sp-thinkpad-t14--g5-14--wuxga-400n--core-ultra-5-processor-125u--16gb-d/p',
#  'https://www.appinformatica.com/83a2001lsp-portatil-lenovo-v17-g4-iru-i3-1315u-17-3-fhd-8gb-256ssd-usb-c-rj45-w/p',
#  'https://www.appinformatica.com/nx-egyeb-00b-ex215-55-ci51235u-8gb-512ssd-15-6in-fhd-w1-1p/p',
#  'https://www.appinformatica.com/zjw-00037-microsoft-laptop6-7ultra-16g-512g-13-5-plat-w11p/p',
#  'https://www.appinformatica.com/zlq-00037-microsoft-laptop6-i7-16gb-512gb-15-sp-plat/p',
#  'https://www.appinformatica.com/zpx-00012-laptop6-5ultra-16g-512g-13-5--bk-w11p/p',
#  'https://www.appinformatica.com/nx-b63eb-001-tmp214-55-14--c5120u-16g-512-ssd-w11p/p',
#  'https://www.appinformatica.com/21ks000bsp-p16s-g3-ult7-155h-32gb-1tb-w11p/p']

# %% [markdown]
# # Scrape Laptop Specifications
# Implement a function to extract detailed specifications from each laptop page, parsing HTML tables and collecting data like processor, memory, storage, graphics, display, operating system, and price.

# %%
def scrape_laptop_specs(url):
    try:
        # Realiza la petición HTTP
        response = requests.get(url)
        response.raise_for_status()  # Raises HTTPError for bad responses (4xx, 5xx)

    except requests.RequestException as e:
        print(f"Error al realizar la petición HTTP: {e}")
        return None

    try:
        soup = BeautifulSoup(response.text, "html.parser")
        
        # Características del portátil
        sections = {}

        # URL del producto
        sections["URL"] = url
        
        # Título del portátil
        title = soup.find("h1", class_="vtex-store-components-3-x-productNameContainer vtex-store-components-3-x-productNameContainer--quickview mv0 t-heading-4")
        if title:
            sections["Titulo"] = title.text
        
        # Marca
        marca = soup.find("span", class_="ticnova-commons-components-0-x-ProductInfo c-action-primary ml2")
        if marca:
            sections['Marca'] = marca.text

        # Se buscan todas las tablas con la clase utilizada en las especificaciones
        tables = soup.find_all("table", class_="vtex-table-description-extended_carac")
        
        # Iteramos sobre cada tabla
        for table in tables:
            current_section = None
            # Iteramos sobre las filas que contienen la clase indicativa
            for row in table.find_all("tr", class_="vtex-table-description-row"):
                try:
                    # Si la fila tiene un <td> con colspan="2" y un div de título, es un encabezado de sección
                    header_td = row.find("td", colspan="2")
                    if header_td:
                        title_div = header_td.find("div", class_="vtex-table-description-title")
                        if title_div:
                            current_section = title_div.get_text(strip=True)
                            sections.setdefault(current_section, {})
                            continue

                    # Si la fila contiene clave y valor, los extraemos
                    key_td = row.find("td", class_="vtex-table-description-key")
                    value_td = row.find("td", class_="vtex-table-description-value")
                    if key_td and value_td and current_section:
                        key = key_td.get_text(strip=True)
                        value = value_td.get_text(strip=True)
                        sections[current_section][key] = value
                except Exception as e:
                    print(f"Error al procesar una fila de la tabla: {e}")
                    continue

        # Mapeamos las secciones extraídas a los campos requeridos:
        mapping = {
            "Procesador": "Procesador",
            "Memoria": "RAM",
            "Medios de almacenaje": "Almacenamiento",
            "Gráficos": "Graficos",
            "Exhibición": "Pantalla",
            "Software": "Sistema Operativo",
            "Batería": "Bateria"
        }
        
        try:
            price = soup.find('div', class_='ticnova-commons-components-0-x-price')
            if price:
                sections['Precio'] = price.text.replace('\xa0', '').replace('€', '').strip()
        except Exception as e:
            print(f"Error al extraer el precio: {e}")

        result = {}
        for seccion_original, campo in mapping.items():
            result[campo] = sections.get(seccion_original, {})

        return sections

    except Exception as e:
        print(f"Error general al procesar la página: {e}")
        return None

# Example usage
laptop_specs = scrape_laptop_specs(laptop_links[0])
laptop_specs
# Out:
# {'URL': 'https://www.appinformatica.com/e1504fa-nj158w-portatil-asus-e1504fa-nj158w-amd-r5-7520u-4-3ghz--8gb--512gb-ssd/p',
#  'Titulo': 'PORTATIL ASUS E1504FA-NJ158W AMD R5-7520U 4.3GHZ/ 8GB/ 512GB SSD/ 15.6" FHD/ W11 ',
#  'Marca': 'Asus',
#  'Procesador': {'Fabricante de procesador': 'AMD',
#   'Familia de procesador': 'AMD Ryzen™ 5',
#   'Modelo del procesador': '7520U',
#   'Frecuencia del procesador': '2,8 GHz',
#   'Frecuencia del procesador turbo': '4,3 GHz',
#   'Caché del procesador': '6 MB',
#   'Tipo de cache en procesador': 'L2 & L3',
#   'Número de núcleos de procesador': '4'},
#  'Memoria': {'Memoria interna': '8 GB',
#   'Tipo de memoria interna': 'LPDDR5-SDRAM',
#   'Forma de factor de memoria': 'Incorporado',
#   'Memoria interna máxima': '8 GB'},
#  'Medios de almacenaje': {'Capacidad total de almacenaje': '512 GB',
#   'Unidad de almacenamiento': 'SSD',
#   'Capacidad total de SSD': '512 GB',
#   'Número de unidades SSD instalados': '1',
#   'SDD, capacidad': '512 GB',
#   'Interfaces del SDD': 'PCI Express 3.0',
#   'NVMe': 'Si',
#   'Factor de forma de disco SSD': 'M.2',
#   'Tipo de unidad óptica': 'No'},
#  'Gráficos': {'Adaptador de gráficos discreto': 'No',
#   'Modelo de adaptador de gráficos discretos': 'No disponible',
#   'Adaptador gráfico incorporado': 'Si',
#   'Modelo de adaptador gráfico incorporado': 'AMD Radeon 610M'},
#  'Exhibición': {'Diagonal de la pantalla': '39,6 cm (15.6")',
#   'Resolución de la pantalla': '1920 x 1080 Pixeles',
#   'Pantalla táctil': 'No',
#   'Tipo HD': 'Full HD',
#   'Relación de aspecto nativa': '16:9',
#   'Pantalla antirreflectante': 'Si',
#   'Espacio de color RGB': 'NTSC',
#   'Gama de colores': '45%',
#   'Brillo de pantalla': '250 cd / m²',
#   'Retroiluminación LED': 'Si',
#   'Tipo de pantalla': 'TN'},
#  'Software': {'Sistema operativo instalado': 'Windows 11 Home',
#   'Arquitectura del sistema operativo': '64 bits',
#   'Software de prueba': '1-month trial for new Microsoft 365 customers. Credit card required, McAfee LiveSafe 30 days'},
#  'Batería': {'Tecnología de batería': 'Ión de litio',
#   'Número de celdas de batería': '3',
#   'Capacidad de batería': '42 Wh'},
#  'Audio': {'Sistema de audio': 'SonicMaster', 'Micrófono incorporado': 'Si'},
#  'Teclado': {'Dispositivo apuntador': 'Touchpad', 'Teclado numérico': 'Si'},
#  'Cámara fotográfica': {'Tipo de cámara frontal HD': 'HD',
#   'Cámara frontal': 'Si',
#   'Cámara con configuración de privacidad': 'Si',
#   'Tipo de privacidad': 'Tapa de obturador'},
#  'Conexión': {'Conexión a red móvil': 'No',
#   'Estándar Wi-Fi': 'Wi-Fi 6E (802.11ax)',
#   'Wi-Fi estándares': 'Wi-Fi 6E (802.11ax)',
#   'Tipo de antena': '1x1',
#   'Bluetooth': 'Si',
#   'Versión de Bluetooth': '5.3',
#   'Ethernet': 'No'},
#  'Control de energía': {'Potencia de adaptador AC': '45 W',
#   'Frecuencia de adaptador AC': '50 - 60 Hz',
#   'Corriente de salida de adaptador AC': '2,37 A',
#   'Voltaje de entrada de adaptador AC': '100 - 240 V',
#   'Voltaje de salida de adaptador AC': '19 V'},
#  'Puertos e Interfaces': {'Cantidad de puertos USB 2.0': '1',
#   'Cantidad de puertos tipo A USB 3.2 Gen 1 (3.1 Gen 1)': '1',
#   'Cantidad de puertos tipo C USB 3.2 Gen 1 (3.1 Gen 1)': '1',
#   'Número de puertos HDMI': '1',
#   'Versión HDMI': '1.4',
#   'Combo de salida de auriculares / micrófono del puerto': 'Si',
#   'Tipo de puerto de carga': 'Toma de entrada de CC',
#   'Conector cilíndrico del adaptador de CA': '4.5 mm'},
#  'Seguridad': {'Módulo de plataforma confiable (TPM)': 'Si',
#   'Protección mediante contraseña': 'Si',
#   'Protección con contraseña': 'BIOS, Usuario'},
#  'Empaquetado': {'Peso del paquete': '3 kg',
#   'Profundidad del paquete': '65 mm',
#   'Altura del paquete': '288 mm',
#   'Ancho del paquete': '481 mm'},
#  'Diseño': {'Tipo de producto': 'Portátil',
#   'Color del producto': 'Plata',
#   'Factor de forma': 'Concha',
#   'Año de introducción': '2023',
#   'Nombre del color': 'Cool Silver',
#   'Material de la carcasa': 'Plástico'},
#  'Peso y dimensiones': {'Peso': '1,63 kg',
#   'Ancho': '360,3 mm',
#   'Profundidad': '232,5 mm',
#   'Altura': '17,9 mm'},
#  'Precio': '599,00'}

# %% [markdown]
# # Insert Data into MongoDB
# Connect to MongoDB and insert the scraped laptop specifications, creating a collection for appinformatica laptops similar to the pcbox database structure.

# %%
# Insert Data into MongoDB

# Connect to MongoDB
client = MongoClient('mongodb://localhost:27017/')
db = client['appinformatica']
collection = db['portatiles']

# Parse each specs_json into a dict and insert into MongoDB
all_laptops_specs = []

for link in laptop_links:
    if any(json.loads(specs_str).get("URL") == link for specs_str in all_laptops_specs):
        print(f"Skipping {link} - already processed")
        continue
    try:
        specs = scrape_laptop_specs(link)
        if specs is not None:
            try:
                specs_json = json.dumps(specs, indent=4, ensure_ascii=False)
                all_laptops_specs.append(specs_json)
            except json.JSONEncodeError as e:
                print(f"Error encoding JSON for {link}: {e}")
    except Exception as e:
        print(f"Error processing link {link}: {e}")
        continue

# Insert documents into MongoDB
for laptop_specs_json in all_laptops_specs:
    # Parse JSON string into dict if needed
    if isinstance(laptop_specs_json, str):
        laptop_specs_dict = json.loads(laptop_specs_json)
    else:
        laptop_specs_dict = laptop_specs_json
    
    # Insert document
    collection.insert_one(laptop_specs_dict)

# %% [markdown]
# # Simplify Specifications
# Create helper functions to simplify and standardize the raw specifications data, extracting relevant information like processor model, RAM capacity, storage size, and screen dimensions.

# %%
# Simplify Specifications

def simplify_procesador(proc_dict):
    fabricante = proc_dict.get("Fabricante de procesador", "").strip()
    familia = proc_dict.get("Familia de procesador", "").strip()
    modelo = proc_dict.get("Modelo del procesador", "").strip()
    # Eliminar símbolos de marca (® y ™)
    familia_clean = re.sub(r"[®™]", "", familia).strip()
    # Si el fabricante no está incluido, lo anteponemos
    if fabricante and fabricante not in familia_clean:
        familia_clean = f"{fabricante} {familia_clean}".strip()
    # Si el modelo empieza con el mismo token final de la familia, lo eliminamos para evitar duplicados
    last_token = familia_clean.split()[-1]
    if modelo.startswith(last_token):
        new_model = modelo[len(last_token):]
        # Si new_model comienza con guión, lo concatenamos directamente
        if new_model.startswith("-"):
            final = f"{familia_clean}{new_model}"
        else:
            final = f"{familia_clean}-{modelo}"
    else:
        final = f"{familia_clean}-{modelo}"
    return final

def simplify_ram(ram_dict):
    # Extrae el número de GB desde "Memoria interna" (por ejemplo, "8 GB")
    ram_value = ram_dict.get("Memoria interna", "")
    match = re.search(r"(\d+)", ram_value)
    return match.group(1) if match else ""

def simplify_tipo_ram(ram_dict):
    tipo_ram = ram_dict.get("Tipo de memoria interna", "")
    # Extrae la parte DDR (por ejemplo, "DDR4" de "DDR4-SDRAM")
    match = re.search(r"(DDR\d+)", tipo_ram, re.IGNORECASE)
    return match.group(1).upper() if match else ""

def simplify_almacenamiento(alm_dict):
    # Se prefiere "Capacidad total de SSD", pero si no existe se usa "SDD, capacidad"
    valor = alm_dict.get("Capacidad total de SSD", "") or alm_dict.get("SDD, capacidad", "")
    match = re.search(r"(\d+)", valor)
    return match.group(1) if match else ""

def simplify_graficos(graf_dict):
    return graf_dict.get("Modelo de adaptador gráfico incorporado", "").strip()

def simplify_pantalla(pant_dict):
    diag = pant_dict.get("Diagonal de la pantalla", "")
    # Se extrae la medida en pulgadas que aparece entre paréntesis, por ejemplo: (15.6")
    match = re.search(r"\(([\d\.]+)\"", diag)
    return match.group(1) if match else ""

def simplify_resolucion(pant_dict):
    resol = pant_dict.get("Resolución de la pantalla", "")
    # Se buscan los dos números (ancho y alto)
    numbers = re.findall(r"(\d+)", resol)
    if len(numbers) >= 2:
        return f"{numbers[0]}x{numbers[1]}"
    return ""

def simplify_sistema(soft_dict):
    return soft_dict.get("Sistema operativo instalado", "").strip()

def simplify_bateria(bat_dict):
    bat = bat_dict.get("Capacidad de batería", "")
    match = re.search(r"(\d+)", bat)
    return match.group(1) if match else ""

def simplify_specs(specs):
    simplified = {}
    simplified["Procesador"] = simplify_procesador(specs.get("Procesador", {}))
    simplified["RAM"] = simplify_ram(specs.get("Memoria", {}))
    simplified["Tipo RAM"] = simplify_tipo_ram(specs.get("Memoria", {}))
    simplified["Almacenamiento"] = simplify_almacenamiento(specs.get("Medios de almacenaje", {}))
    simplified["Graficos"] = simplify_graficos(specs.get("Gráficos", {}))
    simplified["Pantalla"] = simplify_pantalla(specs.get("Exhibición", {}))
    simplified["Resolucion"] = simplify_resolucion(specs.get("Exhibición", {}))
    simplified["Sistema Operativo"] = simplify_sistema(specs.get("Software", {}))
    simplified["Bateria"] = simplify_bateria(specs.get("Batería", {}))
    simplified["Precio"] = specs.get("Precio", "")
    return simplified

# %% [markdown]
# # Export to CSV
# Generate a CSV file with the simplified laptop specifications, ensuring consistent column naming and data formatting to match the PCBox dataset structure.

# %%
import os

# Export to CSV

# Use the dataset_portatils list that already contains simplified specifications
# No need to process all_laptops_specs again

# Define the columns for the CSV in the desired order
fieldnames = [
    "Procesador",
    "RAM",
    "Tipo RAM",
    "Almacenamiento",
    "Graficos",
    "Pantalla",
    "Resolucion",
    "Sistema Operativo",
    "Bateria",
    "Precio"
]

# Check if file exists and load existing data to avoid duplicates
existing_data = []
try:
    if os.path.exists("specs_simplified.csv"):
        with open("specs_simplified.csv", "r", encoding="utf-8") as csvfile:
            reader = csv.DictReader(csvfile)
            for row in reader:
                existing_data.append(row)
        
        print(f"Loaded {len(existing_data)} existing entries from CSV")
    else:
        print("No existing CSV file found, will create new file")
except Exception as e:
    print(f"Error loading existing data: {e}")
    existing_data = []

# Identify unique entries by comparing processors and other key specs
unique_specs = {}
try:
    # Process existing entries first
    for laptop in existing_data:
        # Create a unique key based on multiple fields to identify duplicates
        key = f"{laptop.get('Procesador', '')}-{laptop.get('RAM', '')}-{laptop.get('Almacenamiento', '')}-{laptop.get('Pantalla', '')}"
        unique_specs[key] = laptop
    
    # Add new entries from dataset_portatils
    for laptop in dataset_portatils:
        # Create a unique key based on multiple fields to identify duplicates
        key = f"{laptop.get('Procesador', '')}-{laptop.get('RAM', '')}-{laptop.get('Almacenamiento', '')}-{laptop.get('Pantalla', '')}"
        unique_specs[key] = laptop

    print(f"Total unique laptops: {len(unique_specs)}")
    print(f"New entries added: {len(unique_specs) - len(existing_data)}")
except Exception as e:
    print(f"Error processing laptop data: {e}")

# Write all unique specs to CSV
try:
    with open("specs_simplified.csv", "w", newline="", encoding="utf-8") as csvfile:
        writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
        writer.writeheader()
        for laptop in unique_specs.values():
            writer.writerow(laptop)
    print(f"Successfully exported {len(unique_specs)} laptop specifications to specs_simplified.csv")
except Exception as e:
    print(f"Error writing CSV file: {e}")
# Out:
# Loaded 247 existing entries from CSV
# Total unique laptops: 183
# New entries added: -64
# Successfully exported 183 laptop specifications to specs_simplified.csv
